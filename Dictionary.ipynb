# %% [markdown]
# <a href="https://colab.research.google.com/github/486705367/486705367/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dictionary
student = {"name": "Alice", "age": 20, "grade": "A"}
print(student["name"])   # Access
student["age"] = 21      # Update
print(student)
# Out:
# Alice
# {'name': 'Alice', 'age': 21, 'grade': 'A'}

# %%
#sets
a = {1, 2, 3, 8}
b = {3, 4, 5, 6,6}
print("Union:", a | b)
print("Intersection:", a & b)
print("Difference:", b - a)
b
# Out:
# Union: {1, 2, 3, 4, 5, 6, 8}
# Intersection: {3}
# Difference: {4, 5, 6}
# {3, 4, 5, 6}

# %%
students = [
    {"name": "Alice", "grade": "A"},
    {"name": "Bob", "grade": "B"}
]
print(students[1]["name"])
# Out:
# Bob

# %%
#Activity 1: Tuple – Coordinates
coordinates = (5, 10)
print("X =", coordinates[0])
print("Y =", coordinates[1])
# Out:
# X = 5
# Y = 10

# %%
#Activity 2: Dictionary – Student Grades
grades = {"Alice": 85, "Bob": 78, "Charlie": 92}

avg = sum(grades.values()) / len(grades)
print("Average Grade:", avg)
# Out:
# Average Grade: 85.0

# %%
#Activity 3: Sets – Common Elements
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7]

set1 = set(list1)
set2 = set(list2)

print("Common elements:", set1 & set2)
# Out:
# Common elements: {4, 5}

# %%
#Exercise – Contact Book with Dictionaries
# Contact Book Program
contacts = {}

def add_contact(name, phone):
    contacts[name] = phone
    print(f"Added {name} : {phone}")

def view_contacts():
    for name, phone in contacts.items():
        print(name, ":", phone)

def search_contact(name):
    if name in contacts:
        print(name, ":", contacts[name])
    else:
        print("Contact not found.")

# Example usage
add_contact("Ankit", "12345")
add_contact("Ani", "98765")
view_contacts()
search_contact("Alice")
# Out:
# Added Alice : 12345
# Added Bob : 98765
# Alice : 12345
# Bob : 98765
# Alice : 12345
